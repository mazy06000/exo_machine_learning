# %%
import numpy as np

# %%
x = np.linspace(0,2,10)
y = x**2
print(x)
# Out:
# [0.         0.22222222 0.44444444 0.66666667 0.88888889 1.11111111
#  1.33333333 1.55555556 1.77777778 2.        ]
# 10

# %% [markdown]
# # 1) Pyplot

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12,8))
plt.plot(x,y)

# %%
plt.figure()
plt.plot(x,y, label='quadratique')
plt.plot(x, x**3, label='cubique')
plt.title('figure 1')
plt.xlabel('axe x')
plt.ylabel('axe y')
plt.legend()
plt.show()
plt.savefig('figure.png')

# %%
plt.scatter(x,y) #nuage de point

# %% [markdown]
# # Subplot

# %%
plt.figure()
plt.subplot(2,2,1)
plt.plot(x,y, c='r')
plt.title('graphique 1')

plt.subplot(2,2,2)
plt.plot(x,np.sin(x),c='b')
plt.plot(x,np.cos(x),c='y')
plt.title('graphique2')
# Out:
# Text(0.5, 1.0, 'graphique2')

# %% [markdown]
# # OOP (non conseillé)

# %%
fig, ax = plt.subplots()
ax.plot(x,y)

# %%
#opp plus interessante car plus de possibilité
fig, ax = plt.subplots(2,1,sharex=True)
ax[0].plot(x,y)
ax[1].plot(x,np.sin(x))
plt.show()

# %% [markdown]
# # EXERCICE

# %%
dataset = {f'experience{i}': np.random.randn(100,3) for i in range(4)}
dataset
# Out:
# {'experience0': array([[-0.26984562,  1.03583785, -0.97053315],
#         [ 1.76660815, -1.23865251,  1.15898965],
#         [ 0.16506684,  0.24806482, -0.01012663],
#         [ 0.09077814, -0.28346274,  1.47123344],
#         [ 0.39238292,  0.31885338,  1.0248748 ],
#         [-1.8344047 ,  1.50980353, -0.40056338],
#         [-0.58591048, -0.8977918 ,  0.7238309 ],
#         [-0.05964052, -1.31170226,  0.66259309],
#         [ 2.32913537, -0.70368704,  0.46697217],
#         [ 2.63253111,  0.21918447, -0.18917034],
#         [-0.2906471 , -0.5225826 ,  1.02274759],
#         [-1.89223119, -0.62143681,  0.81451513],
#         [-0.30786614,  0.08103409, -2.0178584 ],
#         [-0.33973349,  0.12639094,  0.78772701],
#         [ 0.33145818,  0.74576257,  0.75719227],
#         [ 0.63421058,  0.10607401,  1.75352221],
#         [ 0.34624786, -1.86518358,  0.13402828],
#         [ 0.94329809,  0.06839492, -0.493249  ],
#         [ 0.51176909, -0.98849152,  1.51052432],
# ...

# %%
def graphique(dataset):
    for i in range(len(dataset)):
        fig = dataset['experience'+str(i)]
        plt.figure()
        plt.subplot(4,1,i+1)
        plt.plot(fig)

# %%
graphique(dataset)

# %% [markdown]
# ## Correction

# %%
def graphique2(data):
    n= len(data)
    plt.figure(figsize=(12,8))
    for k, i in zip(data.keys(), range(1, n+1)):
        plt.subplot(n,1,i)
        plt.plot(data[k])
        plt.title(k)
    plt.show()

# %%
graphique2(dataset)
