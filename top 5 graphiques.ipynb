# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()

x = iris.data
y = iris.target
names = list(iris.target_names)

print(f'x contient {x.shape[0]} exemples et {x.shape[1]} variables')
print(f'il y a {np.unique(y).size} classes')
# Out:
# x contient 150 exemples et 4 variables
# il y a 3 classes

# %% [markdown]
# # n°5 graphiques de classification

# %%
plt.scatter(x[:,0], x[:,1], c=y, alpha=0.5, s=x[:,2]*100) #alpha=transparence du point #s=largeur des points
plt.xlabel('longueur sépal')
plt.ylabel('largeur sépal')
# Out:
# Text(0, 0.5, 'largeur sépal')

# %% [markdown]
# ## n°4 graphique 3D

# %%
# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D

# %%
ax = plt.axes(projection='3d')
ax.scatter(x[:,0], x[:,1], x[:,2], x[:,3], c=y)
# Out:
# C:\Users\Toufik\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\art3d.py:763: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if zdir == 'x':
# C:\Users\Toufik\anaconda3\lib\site-packages\mpl_toolkits\mplot3d\art3d.py:765: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif zdir == 'y':

# %%
f = lambda x,y: np.sin(x) + np.cos(x+y)

# %%
X = np.linspace(0,5,100)
Y = np.linspace(0,5,100)
X,Y = np.meshgrid(X,Y)

Z = f(X,Y)

# %%
Z.shape
# Out:
# (100, 100)

# %%
ax = plt.axes(projection='3d')
ax.plot_surface(X,Y,Z,cmap='plasma')

# %% [markdown]
# ## n°3 Histogramme

# %%
plt.hist(x[:,0], bins=30)
plt.hist(x[:,1], bins=30)
# Out:
# (array([ 1.,  0.,  3.,  4.,  0.,  3.,  8.,  5.,  9., 14.,  0., 10., 26.,
#         11.,  0., 13.,  6., 12.,  6.,  4.,  0.,  3.,  6.,  2.,  0.,  1.,
#          1.,  1.,  0.,  1.]),
#  array([2.  , 2.08, 2.16, 2.24, 2.32, 2.4 , 2.48, 2.56, 2.64, 2.72, 2.8 ,
#         2.88, 2.96, 3.04, 3.12, 3.2 , 3.28, 3.36, 3.44, 3.52, 3.6 , 3.68,
#         3.76, 3.84, 3.92, 4.  , 4.08, 4.16, 4.24, 4.32, 4.4 ]),
#  <BarContainer object of 30 artists>)

# %%
plt.hist2d(x[:,0],x[:,1])
plt.xlabel('longueur sépal')
plt.xlabel('largeur sépal')
plt.colorbar()

# %%
from scipy import misc
face = misc.face(gray=True)
#plt.imshow(face,cmap='gray')
plt.hist(face.ravel(),bins=255)
plt.show()

# %% [markdown]
# ## n°2 contour plot

# %%
plt.contour(X,Y,Z, 20)

# %%
plt.contourf(X,Y,Z,20, cmap='RdGy')

# %% [markdown]
# ## n°1 imshow

# %%
plt.imshow(face)

# %%
plt.imshow(np.corrcoef(X.T))
plt.colorbar()
plt.show()
# Out:
# C:\Users\Toufik\anaconda3\lib\site-packages\numpy\lib\function_base.py:2559: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[:, None]
# C:\Users\Toufik\anaconda3\lib\site-packages\numpy\lib\function_base.py:2560: RuntimeWarning: invalid value encountered in true_divide
#   c /= stddev[None, :]

# %%
plt.imshow(Z)

# %% [markdown]
# # Exercice

# %%
def graphique2(data):
    n= len(data)
    plt.figure(figsize=(12,8))
    for i in range(n-1):
        plt.scatter(x[:,i], x[:,i+1])
    plt.show()

# %%
graphique2(x)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-f25599d0d1c4> in <module>
# ----> 1 graphique2(x)
#
# <ipython-input-18-349241b23627> in graphique2(data)
#       3     plt.figure(figsize=(12,8))
#       4     for i in range(n-1):
# ----> 5         plt.scatter(x[:,i], x[:,i+1])
#       6     plt.show()
#
# IndexError: index 4 is out of bounds for axis 1 with size 4

# %%
x

# %% [markdown]
# ## Correction

# %%
n = x.shape[1]
plt.figure()
for i in range(n):
    plt.subplot(n//2, n//2, i+1)
    plt.scatter(x[:,0], x[:,i], c=y)
    plt.xlabel('0')
    plt.ylabel(i)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
