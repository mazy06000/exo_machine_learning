# %% [markdown]
# ## Broadcasting

# %%
import numpy as np

# %%
np.random.seed(0)
A = np.random.randint(0,10, [2,3])
B = np.ones(A.shape)

# %%
A
# Out:
# array([[5, 0, 3],
#        [3, 7, 9]])

# %%
B
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
A + B
# Out:
# array([[ 6.,  1.,  4.],
#        [ 4.,  8., 10.]])
